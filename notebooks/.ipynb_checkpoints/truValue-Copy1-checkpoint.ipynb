# %% [markdown]
# # TruValue

# %%
import requests
import json
import pprint

import pandas as pd
import numpy as np

from pathlib import Path

# %% [markdown]
# ### Connect to API

# %%
# Load connection data
API_ENDPOINT = 'https://api.insight360.io/v3/'
API_TOKEN_PATH = Path('/home/ubuntu/newsfeed/access/truValue_api.txt')
with API_TOKEN_PATH.open('r') as fin:
    api_token = fin.read().strip()

# %%
isin = 'US5949181045'
headers = {
    'accesstoken': api_token
}

# %%
def make_request(url, params, headers=headers, doPrint=True):    
    r = requests.get(url=url, headers=headers, params=params)
    if doPrint:
        print('response code: {}\n'.format(r.status_code))
        pp = pprint.PrettyPrinter()
        pp.pprint(r.json())
    else:
        return r.json()

# %% [markdown]
# #### Company Score

# %%
score_url = API_ENDPOINT + 'data/companies/' + isin + '/score'
score_payload = {
    'score_type': 'pulse,insight,momentum',
    'includeArticles': 'true',
    'percentile': 'true',
    'volume': 'true',
    'metrics': 'allmaterial'
}
make_request(url=score_url, params=score_payload)
# Out:
# response code: 200
#
# {'CUSIP': '594918104',
#  'ISIN': 'US5949181045',
#  'SEDOL': '2588173',
#  'TICKER': 'MSFT',
#  'articleList': [{'author': '',
#                   'categories': ['DataSecurityAndCustomerPrivacy'],
#                   'pubDate': '2018-11-06T14:00:00.000Z',
#                   'source': 'Engadget',
#                   'title': "Microsoft's Bitlocker compromised by bad SSD "
#                            'encryption',
#                   'url': 'https://www.engadget.com/2018/11/06/microsofts-bitlocker-compromised-by-bad-ssd-encryption/'},
#                  {'author': '',
#                   'categories': ['DataSecurityAndCustomerPrivacy'],
#                   'pubDate': '2018-11-06T05:47:38.000Z',
#                   'source': 'The Statesman',
#                   'title': 'Microsoft doesn’t use customers’ data for profit: '
#                            'Satya Nadella',
#                   'url': 'http://ct.moreover.com/?a=37605586958&p=4la&v=1&x=FnVx57yluGMZDtb7xv2I2Q'}],
#  'companyName': 'Microsoft',
#  'date': '2018-11-06T00:00:00.000Z',
#  'hourMs': 1541462400000,
#  'insight': {'CompetitiveBehavior': 47.850485117844116,
#              'CompetitiveBehaviorIndustryPercentile': 47.160000000000004,
#              'DataSecurityAndCustomerPrivacy': 59.46544689406273,
#              'DataSecurityAndCustomerPrivacyIndustryPercentile': 22.902985074626866,
#              'DiversityAndInclusion': 58.58646323565541,
#              'DiversityAndInclusionIndustryPercentile': 21.38888888888889,
#              'EnergyManagement': 77.53969126686643,
#              'EnergyManagementIndustryPercentile': 71.77499999999999,
#              'MaterialityScore': 58.170437409925675,
#              'MaterialityScoreIndustryPercentile': 34.955555555555556,
#              'RecruitmentDevelopmentAndRetention': 58.84455752684249,
#              'RecruitmentDevelopmentAndRetentionIndustryPercentile': 42.23394495412844,
#              'SystemicRiskManagement': 34.123815248782655,
#              'SystemicRiskManagementIndustryPercentile': 22.963917525773198,
#              'WaterAndWastewaterManagement': 49.24450300307576,
#              'WaterAndWastewaterManagementIndustryPercentile': 27.909574468085104},
#  'mode': 'Insight360 SASB Edition API',
#  'momentum': {'CompetitiveBehavior': 30.241164097462693,
#               'CompetitiveBehaviorIndustryPercentile': 25.56,
#               'DataSecurityAndCustomerPrivacy': 55.46210550256788,
#               'DataSecurityAndCustomerPrivacyIndustryPercentile': 59.54776119402985,
#               'DiversityAndInclusion': 27.991237899952576,
#               'DiversityAndInclusionIndustryPercentile': 17.72222222222222,
#               'EnergyManagement': 69.97040141864538,
#               'EnergyManagementIndustryPercentile': 77.34375,
#               'MaterialityScore': 54.796033300744675,
#               'MaterialityScoreIndustryPercentile': 56.711111111111116,
#               'RecruitmentDevelopmentAndRetention': 67.31108387139389,
#               'RecruitmentDevelopmentAndRetentionIndustryPercentile': 66.60550458715596,
#               'SystemicRiskManagement': 22.807194906478966,
#               'SystemicRiskManagementIndustryPercentile': 15.054123711340205,
#               'WaterAndWastewaterManagement': 13.335283779311796,
#               'WaterAndWastewaterManagementIndustryPercentile': 3.1595744680851063},
#  'pulse': {'CompetitiveBehavior': 49.147062778712574,
#            'DataSecurityAndCustomerPrivacy': 61.925400377598216,
#            'DiversityAndInclusion': 70.87732733397499,
#            'EnergyManagement': 75.9348581706261,
#            'MaterialityScore': 62.00370403663113,
#            'RecruitmentDevelopmentAndRetention': 69.15836943832822,
#            'SystemicRiskManagement': 35.867973616007625,
#            'WaterAndWastewaterManagement': 60.49826874259628},
#  'volume': {'AllCategoriesArticleVolumeDaily': 4,
#             'AllCategoriesArticleVolumeTTM': 3151,
#             'AllCategoriesCategoryVolumeDaily': 5,
#             'AllCategoriesCategoryVolumeTTM': 4510,
#             'CompetitiveBehaviorDaily': 0,
#             'CompetitiveBehaviorTTM': 247,
#             'DataSecurityAndCustomerPrivacyDaily': 2,
#             'DataSecurityAndCustomerPrivacyTTM': 934,
#             'DiversityAndInclusionDaily': 0,
#             'DiversityAndInclusionTTM': 201,
#             'EnergyManagementDaily': 0,
#             'EnergyManagementTTM': 187,
#             'RecruitmentDevelopmentAndRetentionDaily': 0,
#             'RecruitmentDevelopmentAndRetentionTTM': 232,
#             'SasbMaterialityArticleVolumeDaily': 2,
#             'SasbMaterialityArticleVolumeTTM': 1753,
#             'SasbMaterialityCategoryVolumeDaily': 2,
#             'SasbMaterialityCategoryVolumeTTM': 1865,
#             'SystemicRiskManagementDaily': 0,
#             'SystemicRiskManagementTTM': 34,
#             'WaterAndWastewaterManagementDaily': 0,
#             'WaterAndWastewaterManagementTTM': 30}}

# %% [markdown]
# #### Momentum Score

# %%
momentum_url = API_ENDPOINT + 'data/companies/' + isin + '/momentum'
momentum_payload = {
    'start_date': '2017-01-01',
    'end_date': '2018-11-02',
    'percentile': 'true',
    'metrics': 'allmaterial',
}
make_request(url=momentum_url, params=momentum_payload)
# Out:
# response code: 200
#
# {'CUSIP': '594918104',
#  'ISIN': 'US5949181045',
#  'SEDOL': '2588173',
#  'TICKER': 'MSFT',
#  'companyName': 'Microsoft',
#  'firstInsightDate': {'CompetitiveBehavior': {'date': '2007-01-15T00:00:00.000Z',
#                                               'hourMs': 1168819200000,
#                                               'value': 31.461458834883754},
#                       'DataSecurityAndCustomerPrivacy': {'date': '2007-01-18T00:00:00.000Z',
#                                                          'hourMs': 1169078400000,
#                                                          'value': 69.08074629079137},
#                       'DiversityAndInclusion': {'date': '2007-04-01T00:00:00.000Z',
#                                                 'hourMs': 1175385600000,
#                                                 'value': 72.3515},
#                       'EnergyManagement': {'date': '2007-02-02T00:00:00.000Z',
#                                            'hourMs': 1170374400000,
#                                            'value': 73.724908343715},
#                       'MaterialityScore': {'date': '2007-01-15T00:00:00.000Z',
#                                            'hourMs': 1168819200000,
#                                            'value': 54.31815653758418},
#                       'RecruitmentDevelopmentAndRetention': {'date': '2007-02-12T00:00:00.000Z',
#                                                              'hourMs': 1171238400000,
#                                                              'value': 67.89839051749017},
#                       'SystemicRiskManagement': {'date': '2007-03-02T00:00:00.000Z',
#                                                  'hourMs': 1172793600000,
#                                                  'value': 51.5165},
#                       'WaterAndWastewaterManagement': {'date': '2007-02-02T00:00:00.000Z',
#                                                        'hourMs': 1170374400000,
#                                                        'value': 50}},
#  'mode': 'Insight360 SASB Edition API',
#  'momentum': {'CompetitiveBehavior': {'raw': 0.0075484099664587904,
#                                       'refined': 71.18078855818187},
#               'DataSecurityAndCustomerPrivacy': {'raw': -0.0006873789245157153,
#                                                  'refined': 50},
#               'DiversityAndInclusion': {'raw': -0.01668042484047253,
#                                         'refined': 20.038788091963543},
#               'EnergyManagement': {'raw': 0.005917563426042874,
#                                    'refined': 68.96429625222919},
#               'MaterialityScore': {'raw': 0.0017379240717719834,
#                                    'refined': 55.85174038810887},
#               'RecruitmentDevelopmentAndRetention': {'raw': 0.00982834046642492,
#                                                      'refined': 73.80153578444855},
#               'SystemicRiskManagement': {'raw': -0.0033816525389977923,
#                                          'refined': 37.03407814216617},
#               'WaterAndWastewaterManagement': {'raw': -0.011463452508262511,
#                                                'refined': 23.49034741423833}}}

# %% [markdown]
# #### Load ISINs

# %%
reut = pd.read_excel('/home/ubuntu/newsfeed/data/Reuters select ESG data only 12k securities.xlsx', header=1)

# %%
isins = reut[reut['TR.ISIN'].apply(lambda x: type(x) == str)]['TR.ISIN']

# %%
def get_score_report(isin, score_type='pulse,insight,momentum', includeArticles='true',
                            percentile='true', volume='true', metrics='allmaterial'):
    score_url = API_ENDPOINT + 'data/companies/' + isin + '/score'
    score_payload = {
        'score_type': score_type,
        'includeArticles': includeArticles,
        'percentile': percentile,
        'volume': volume,
        'metrics': metrics
    }
    isin_json = make_request(url=score_url, params=score_payload, doPrint=False)
    return isin_json
full_scores = {isin: get_score_report(isin) for isin in isins}

# %%
full_scores
# Out:
# {'US0378331005': {'ISIN': 'US0378331005',
#   'CUSIP': '037833100',
#   'SEDOL': '2046251',
#   'TICKER': 'AAPL',
#   'companyName': 'Apple Inc.',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 58.003767285677675,
#    'MaterialityScoreIndustryPercentile': 9.02,
#    'DataSecurityAndCustomerPrivacy': 51.682386375532325,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 10.773529411764706,
#    'DiversityAndInclusion': 47.274744692395196,
#    'DiversityAndInclusionIndustryPercentile': 14.437500000000002,
#    'LifecycleImpactsOfProductsAndServices': 60.661500516932186,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 12.034403669724771,
#    'MaterialsSourcing': 65.7694382772552,
#    'MaterialsSourcingIndustryPercentile': 74.765625,
#    'SupplyChainManagement': 59.4954417624226,
#    'SupplyChainManagementIndustryPercentile': 30.26751592356688},
#   'pulse': {'MaterialityScore': 58.965883521932675,
#    'DataSecurityAndCustomerPrivacy': 50.00371179150824,
#    'DiversityAndInclusion': 21.015739615498678,
#    'LifecycleImpactsOfProductsAndServices': 63.347168195515486,
#    'MaterialsSourcing': 69.73708775950568,
#    'SupplyChainManagement': 48.129263805476214},
#   'momentum': {'MaterialityScore': 29.76218457567835,
#    'MaterialityScoreIndustryPercentile': 25.96,
#    'DataSecurityAndCustomerPrivacy': 37.15333626406994,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 23.876470588235293,
#    'DiversityAndInclusion': 80.62667169591812,
#    'DiversityAndInclusionIndustryPercentile': 85.9375,
#    'LifecycleImpactsOfProductsAndServices': 24.691356872655597,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 17.71100917431193,
#    'MaterialsSourcing': 28.37780013464062,
#    'MaterialsSourcingIndustryPercentile': 17.53125,
#    'SupplyChainManagement': 24.960506751300098,
#    'SupplyChainManagementIndustryPercentile': 13.872611464968152},
#   'volume': {'AllCategoriesArticleVolumeTTM': 1912,
#    'SasbMaterialityArticleVolumeTTM': 1177,
#    'AllCategoriesCategoryVolumeTTM': 2679,
#    'SasbMaterialityCategoryVolumeTTM': 1232,
#    'AllCategoriesCategoryVolumeDaily': 6,
#    'SasbMaterialityCategoryVolumeDaily': 3,
#    'AllCategoriesArticleVolumeDaily': 4,
#    'SasbMaterialityArticleVolumeDaily': 3,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 243,
#    'DiversityAndInclusionDaily': 0,
#    'DiversityAndInclusionTTM': 28,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 681,
#    'MaterialsSourcingDaily': 0,
#    'MaterialsSourcingTTM': 15,
#    'SupplyChainManagementDaily': 3,
#    'SupplyChainManagementTTM': 265},
#   'articleList': [{'pubDate': '2018-11-06T06:48:24.000Z',
#     'title': "Apple's Asia suppliers fall on report iPhone XR production boost canceled",
#     'source': 'Reuters',
#     'author': '',
#     'url': 'http://feeds.reuters.com/~r/reuters/businessNews/~3/9VnfA-2tGiY/apples-asia-suppliers-fall-on-report-iphone-xr-production-boost-canceled-idUSKCN1NB0AF',
#     'categories': ['SupplyChainManagement']},
#    {'pubDate': '2018-11-06T04:13:30.000Z',
#     'title': "Apple's Asia suppliers fall on report it cancelled production boost for iPhone XR",
#     'source': 'Business Times Singapore',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37604380853&p=4la&v=1&x=UI3o67gesdJpvGuqX4TfpQ',
#     'categories': ['SupplyChainManagement']},
#    {'pubDate': '2018-11-06T03:43:50.000Z',
#     'title': "Apple's Asia suppliers fall on report it canceled production boost for iPhone XR",
#     'source': 'Reuters',
#     'author': '',
#     'url': 'http://feeds.reuters.com/~r/reuters/businessNews/~3/a0s9LPnhncA/apples-asia-suppliers-fall-on-report-it-canceled-production-boost-for-iphone-xr-idUSKCN1NB0AF',
#     'categories': ['SupplyChainManagement']},
#    {'pubDate': '2018-11-05T20:01:00.000Z',
#     'title': "Apple's Confusing Mac Lineup: MacBook Air vs. MacBook",
#     'source': 'MacRumors',
#     'author': 'Juli Clover',
#     'url': 'https://www.macrumors.com/2018/11/05/macbook-vs-macbook-air/',
#     'categories': ['LifecycleImpactsOfProductsAndServices']},
#    {'pubDate': '2018-11-05T17:06:38.000Z',
#     'title': 'UPDATE 2-Apple cancels production boost for iPhone XR- Nikkei',
#     'source': 'Reuters',
#     'author': 'Akanksha Rana',
#     'url': 'http://feeds.reuters.com/~r/reuters/companyNews/~3/LG_wbJ_1z6M/update-2-apple-cancels-production-boost-for-iphone-xr-nikkei-idUSL4N1XG3UZ',
#     'categories': ['SupplyChainManagement']},
#    {'pubDate': '2018-11-05T17:33:18.000Z',
#     'title': "iPad Pro reviews are starting to come in, and Apple's new tablet apparently won't replace your laptop - Business Insider",
#     'source': 'Business Insider',
#     'author': 'Avery Hartmans',
#     'url': 'http://news.google.com/news/url?sa=t&fd=R&ct2=us&usg=AFQjCNFEK7chI7SM_Jap2wBiLESFdLXiIg&clid=c3a7d30bb8a4878e06b80cf16b898331&cid=52780090308048&ei=mazgW9ivLNG-hAGi54KABg&url=https://www.businessinsider.com/apple-ipad-pro-review-round-up-2018-11',
#     'categories': ['LifecycleImpactsOfProductsAndServices']},
#    {'pubDate': '2018-11-05T17:33:18.000Z',
#     'title': "iPad Pro reviews are starting to come in, and Apple's new tablet apparently won't replace your laptop",
#     'source': 'Business Insider',
#     'author': 'Avery Hartmans',
#     'url': 'https://www.businessinsider.com/apple-ipad-pro-review-round-up-2018-11',
#     'categories': ['LifecycleImpactsOfProductsAndServices']}]},
#  'US5949181045': {'ISIN': 'US5949181045',
#   'CUSIP': '594918104',
#   'SEDOL': '2588173',
#   'TICKER': 'MSFT',
#   'companyName': 'Microsoft',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 58.15608520353611,
#    'MaterialityScoreIndustryPercentile': 34.79702970297029,
#    'CompetitiveBehavior': 47.85326190609197,
#    'CompetitiveBehaviorIndustryPercentile': 47.33211678832117,
#    'DataSecurityAndCustomerPrivacy': 59.45496793686426,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 22.971556886227546,
#    'DiversityAndInclusion': 58.53665136131971,
#    'DiversityAndInclusionIndustryPercentile': 21.083333333333332,
#    'EnergyManagement': 77.55751463073635,
#    'EnergyManagementIndustryPercentile': 71.77499999999999,
#    'RecruitmentDevelopmentAndRetention': 58.80520246962753,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 42.23394495412844,
#    'SystemicRiskManagement': 34.11715995460789,
#    'SystemicRiskManagementIndustryPercentile': 22.963917525773198,
#    'WaterAndWastewaterManagement': 49.201561305247296,
#    'WaterAndWastewaterManagementIndustryPercentile': 27.909574468085104},
#   'pulse': {'MaterialityScore': 62.14001015046831,
#    'CompetitiveBehavior': 49.147062778712574,
#    'DataSecurityAndCustomerPrivacy': 62.186597245853775,
#    'DiversityAndInclusion': 70.87732733397499,
#    'EnergyManagement': 75.9348581706261,
#    'RecruitmentDevelopmentAndRetention': 69.15836943832822,
#    'SystemicRiskManagement': 35.867973616007625,
#    'WaterAndWastewaterManagement': 60.49826874259628},
#   'momentum': {'MaterialityScore': 54.609786192672274,
#    'MaterialityScoreIndustryPercentile': 56.85148514851485,
#    'CompetitiveBehavior': 30.344548677246596,
#    'CompetitiveBehaviorIndustryPercentile': 25.833941605839414,
#    'DataSecurityAndCustomerPrivacy': 55.0626950744211,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 59.874251497005986,
#    'DiversityAndInclusion': 27.901752600039593,
#    'DiversityAndInclusionIndustryPercentile': 17.72222222222222,
#    'EnergyManagement': 70.03533322313307,
#    'EnergyManagementIndustryPercentile': 77.34375,
#    'RecruitmentDevelopmentAndRetention': 67.21044528260438,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 66.90825688073394,
#    'SystemicRiskManagement': 22.697905413040115,
#    'SystemicRiskManagementIndustryPercentile': 15.054123711340205,
#    'WaterAndWastewaterManagement': 13.18200398373155,
#    'WaterAndWastewaterManagementIndustryPercentile': 3.1595744680851063},
#   'volume': {'AllCategoriesArticleVolumeTTM': 3155,
#    'SasbMaterialityArticleVolumeTTM': 1756,
#    'AllCategoriesCategoryVolumeTTM': 4514,
#    'SasbMaterialityCategoryVolumeTTM': 1868,
#    'AllCategoriesCategoryVolumeDaily': 3,
#    'SasbMaterialityCategoryVolumeDaily': 1,
#    'AllCategoriesArticleVolumeDaily': 2,
#    'SasbMaterialityArticleVolumeDaily': 1,
#    'CompetitiveBehaviorDaily': 0,
#    'CompetitiveBehaviorTTM': 247,
#    'DataSecurityAndCustomerPrivacyDaily': 1,
#    'DataSecurityAndCustomerPrivacyTTM': 936,
#    'DiversityAndInclusionDaily': 0,
#    'DiversityAndInclusionTTM': 201,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 187,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 233,
#    'SystemicRiskManagementDaily': 0,
#    'SystemicRiskManagementTTM': 34,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 30},
#   'articleList': [{'pubDate': '2018-11-06T05:47:38.000Z',
#     'title': 'Microsoft doesn’t use customers’ data for profit: Satya Nadella',
#     'source': 'The Statesman',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37605586958&p=4la&v=1&x=FnVx57yluGMZDtb7xv2I2Q',
#     'categories': ['DataSecurityAndCustomerPrivacy']},
#    {'pubDate': '2018-11-05T23:00:00.000Z',
#     'title': "Microsoft may be the world's largest open source contributor, but developers don't care--yet",
#     'source': 'Linux Today',
#     'author': 'Matt Asay',
#     'url': 'https://www.linuxtoday.com/it_management/microsoft-may-be-the-worlds-largest-open-source-contributor-but-developers-dont-care-yet.html',
#     'categories': ['CompetitiveBehavior']},
#    {'pubDate': '2018-11-05T20:11:52.000Z',
#     'title': 'Heat waste of Microsoft’s submarine data centre not acceptable',
#     'source': 'Daily DataCenter News for the Asia Pacific Region',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37601322212&p=4la&v=1&x=Fkt9HDCihcpfU-fgxE2H3w',
#     'categories': ['GHGEmissions', 'EnergyManagement', 'BiodiversityImpacts']},
#    {'pubDate': '2018-11-05T18:40:00.000Z',
#     'title': 'Microsoft Keeps Its Dukes Up',
#     'source': 'WIRED',
#     'author': 'Declan McCullagh',
#     'url': 'https://www.wired.com/1999/11/microsoft-keeps-its-dukes-up/',
#     'categories': ['CompetitiveBehavior']}]},
#  'US0231351067': {'ISIN': 'US0231351067',
#   'CUSIP': '023135106',
#   'SEDOL': '2000019',
#   'TICKER': 'AMZN',
#   'companyName': 'Amazon.com',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 58.71237354729537,
#    'MaterialityScoreIndustryPercentile': 49.5,
#    'DataSecurityAndCustomerPrivacy': 57.307989525182336,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 34.26923076923077,
#    'DiversityAndInclusion': 60.659781870210246,
#    'DiversityAndInclusionIndustryPercentile': 12.375,
#    'EnergyManagement': 80.10706302789193,
#    'EnergyManagementIndustryPercentile': 76.5,
#    'LifecycleImpactsOfProductsAndServices': 68.79424614927008,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 49.5,
#    'RecruitmentDevelopmentAndRetention': 52.932620115418146,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 53.035714285714285,
#    'WaterAndWastewaterManagement': 45.50041754347194,
#    'WaterAndWastewaterManagementIndustryPercentile': 0},
#   'pulse': {'MaterialityScore': 58.655006133097686,
#    'DataSecurityAndCustomerPrivacy': 58.64676830664668,
#    'DiversityAndInclusion': 51.03402664557852,
#    'EnergyManagement': 80.24080643174018,
#    'LifecycleImpactsOfProductsAndServices': 67.34033365267544,
#    'RecruitmentDevelopmentAndRetention': 50.827128408356074,
#    'WaterAndWastewaterManagement': 50.83481082810557},
#   'momentum': {'MaterialityScore': 27.195716505298474,
#    'MaterialityScoreIndustryPercentile': 22,
#    'DataSecurityAndCustomerPrivacy': 32.07814209322268,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 30.461538461538463,
#    'DiversityAndInclusion': 13.419539229545757,
#    'DiversityAndInclusionIndustryPercentile': 0,
#    'EnergyManagement': 69.87124453946304,
#    'EnergyManagementIndustryPercentile': 63,
#    'LifecycleImpactsOfProductsAndServices': 29.71072565253389,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 26.4,
#    'RecruitmentDevelopmentAndRetention': 32.400896577750785,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 24.75,
#    'WaterAndWastewaterManagement': 12.131586610571699,
#    'WaterAndWastewaterManagementIndustryPercentile': 0},
#   'volume': {'AllCategoriesArticleVolumeTTM': 3871,
#    'SasbMaterialityArticleVolumeTTM': 1361,
#    'AllCategoriesCategoryVolumeTTM': 6858,
#    'SasbMaterialityCategoryVolumeTTM': 1511,
#    'AllCategoriesCategoryVolumeDaily': 4,
#    'SasbMaterialityCategoryVolumeDaily': 0,
#    'AllCategoriesArticleVolumeDaily': 3,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 415,
#    'DiversityAndInclusionDaily': 0,
#    'DiversityAndInclusionTTM': 170,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 72,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 269,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 561,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 24},
#   'articleList': []},
#  'US30303M1027': {'ISIN': 'US30303M1027',
#   'CUSIP': '30303M102',
#   'SEDOL': 'B7TL820',
#   'TICKER': 'FB',
#   'companyName': 'Facebook',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 48.94139137291312,
#    'MaterialityScoreIndustryPercentile': 29.7,
#    'CompetitiveBehavior': 38.68843327142035,
#    'CompetitiveBehaviorIndustryPercentile': 39.12096774193548,
#    'DataSecurityAndCustomerPrivacy': 47.2033097123856,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 14.26271186440678,
#    'DiversityAndInclusion': 47.5075699994994,
#    'DiversityAndInclusionIndustryPercentile': 24,
#    'EnergyManagement': 81.95970772723881,
#    'EnergyManagementIndustryPercentile': 69.98275862068965,
#    'RecruitmentDevelopmentAndRetention': 53.89448892580669,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 45,
#    'WaterAndWastewaterManagement': 36.30128237553706,
#    'WaterAndWastewaterManagementIndustryPercentile': 21.21428571428571},
#   'pulse': {'MaterialityScore': 45.665238054563446,
#    'CompetitiveBehavior': 32.746687480300814,
#    'DataSecurityAndCustomerPrivacy': 42.101607535110006,
#    'DiversityAndInclusion': 42.16935783672472,
#    'EnergyManagement': 84.71566324365355,
#    'RecruitmentDevelopmentAndRetention': 51.54757389938824,
#    'WaterAndWastewaterManagement': 51.66554029260602},
#   'momentum': {'MaterialityScore': 48.04710536249375,
#    'MaterialityScoreIndustryPercentile': 38.362500000000004,
#    'CompetitiveBehavior': 41.13320657370656,
#    'CompetitiveBehaviorIndustryPercentile': 42.314516129032256,
#    'DataSecurityAndCustomerPrivacy': 37.03661457891229,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 15.101694915254239,
#    'DiversityAndInclusion': 28.957308216834555,
#    'DiversityAndInclusionIndustryPercentile': 15,
#    'EnergyManagement': 84.01929107289827,
#    'EnergyManagementIndustryPercentile': 85.34482758620689,
#    'RecruitmentDevelopmentAndRetention': 36.15665868963206,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 36,
#    'WaterAndWastewaterManagement': 26.08125383002283,
#    'WaterAndWastewaterManagementIndustryPercentile': 7.071428571428571},
#   'volume': {'AllCategoriesArticleVolumeTTM': 5225,
#    'SasbMaterialityArticleVolumeTTM': 3711,
#    'AllCategoriesCategoryVolumeTTM': 7262,
#    'SasbMaterialityCategoryVolumeTTM': 4002,
#    'AllCategoriesCategoryVolumeDaily': 18,
#    'SasbMaterialityCategoryVolumeDaily': 7,
#    'AllCategoriesArticleVolumeDaily': 13,
#    'SasbMaterialityArticleVolumeDaily': 6,
#    'CompetitiveBehaviorDaily': 0,
#    'CompetitiveBehaviorTTM': 475,
#    'DataSecurityAndCustomerPrivacyDaily': 5,
#    'DataSecurityAndCustomerPrivacyTTM': 2882,
#    'DiversityAndInclusionDaily': 1,
#    'DiversityAndInclusionTTM': 147,
#    'EnergyManagementDaily': 1,
#    'EnergyManagementTTM': 206,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 252,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 40},
#   'articleList': [{'pubDate': '2018-11-06T12:00:00.000Z',
#     'title': 'Facebook, TVA plan 377MW solar pipeline in Alabama, Tennessee',
#     'source': 'Energy Monitor Worldwide',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37607809153&p=4la&v=1&x=X8A1_9Uri8x-HrgGHvzKNw',
#     'categories': ['EnergyManagement']},
#    {'pubDate': '2018-11-06T12:32:00.000Z',
#     'title': 'European Regulators Probe Facebook Over the Way It Targets Web Users',
#     'source': 'Fortune',
#     'author': 'David Meyer',
#     'url': 'http://fortune.com/2018/11/06/facebook-cambridge-analytica-tracking-probe/',
#     'categories': ['DataSecurityAndCustomerPrivacy',
#      'BusinessEthicsAndTransparencyOfPayments']},
#    {'pubDate': '2018-11-06T11:30:34.000Z',
#     'title': 'UK data watchdog chief says Facebook must change, calls for more regulation',
#     'source': 'Channel NewsAsia',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37607583459&p=4la&v=1&x=aPsLhRSJ8mQjnZ9zQf-blQ',
#     'categories': ['DataSecurityAndCustomerPrivacy']},
#    {'pubDate': '2018-11-06T10:44:15.000Z',
#     'title': 'British watchdog refers Facebook to Irish data body',
#     'source': 'TheStar.com.my',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37607067676&p=4la&v=1&x=jvP2gUjHkhvPuEkaQBtt0A',
#     'categories': ['DataSecurityAndCustomerPrivacy']},
#    {'pubDate': '2018-11-06T07:05:51.000Z',
#     'title': "Facebook should take action now as Myanmar's 2020 election is a likely flashpoint: Report",
#     'source': 'Straits Times',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37605486870&p=4la&v=1&x=JmujARTVyXc22esK5zOZSg',
#     'categories': ['DataSecurityAndCustomerPrivacy',
#      'DiversityAndInclusion',
#      'BusinessEthicsAndTransparencyOfPayments',
#      'HumanRightsAndCommunityRelations']},
#    {'pubDate': '2018-11-06T01:30:00.000Z',
#     'title': "Facebook warns Digital Safety Commissioner 'could limit freedom of expression'",
#     'source': 'Irish Independent',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37603540943&p=4la&v=1&x=o24N4nwqk_QCowmEQaNzQg',
#     'categories': ['DataSecurityAndCustomerPrivacy',
#      'HumanRightsAndCommunityRelations']},
#    {'pubDate': '2018-11-05T23:21:00.000Z',
#     'title': 'TVA, Facebook plan 377MW PV pipeline in Alabama, Tennessee',
#     'source': 'PV Tech',
#     'author': 'Conor Ryan',
#     'url': 'https://www.pv-tech.org/news/tva-facebook-plan-377mw-pv-pipeline-in-alabama-tennessee',
#     'categories': ['EnergyManagement']},
#    {'pubDate': '2018-11-05T18:03:15.000Z',
#     'title': 'TVA announces solar installations being built for Facebook',
#     'source': 'ABC News',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37600688616&p=4la&v=1&x=sXbe3PSrSYGkWyET0ZiX8g',
#     'categories': ['EnergyManagement']}]},
#  'US46625H1005': {'ISIN': 'US46625H1005',
#   'CUSIP': '46625H100',
#   'SEDOL': '2190385',
#   'TICKER': 'JPM',
#   'companyName': 'JPMorgan Chase',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 46.88664314074114,
#    'MaterialityScoreIndustryPercentile': 38.21052631578947,
#    'BusinessEthicsAndTransparencyOfPayments': 31.061997598249498,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 39.81521739130435,
#    'CompensationAndBenefits': 51.68136607211521,
#    'CompensationAndBenefitsIndustryPercentile': 39.875,
#    'DiversityAndInclusion': 62.252506594305565,
#    'DiversityAndInclusionIndustryPercentile': 45,
#    'LifecycleImpactsOfProductsAndServices': 58.25460328479351,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 18.7,
#    'SystemicRiskManagement': 43.25910757261497,
#    'SystemicRiskManagementIndustryPercentile': 42.074999999999996},
#   'pulse': {'MaterialityScore': 56.210200311257175,
#    'BusinessEthicsAndTransparencyOfPayments': 47.712937553467846,
#    'CompensationAndBenefits': 59.464063533556484,
#    'DiversityAndInclusion': 68.3398969455826,
#    'LifecycleImpactsOfProductsAndServices': 56.93786284251057,
#    'SystemicRiskManagement': 35.7300266127365},
#   'momentum': {'MaterialityScore': 54.42829255511219,
#    'MaterialityScoreIndustryPercentile': 71.21052631578948,
#    'BusinessEthicsAndTransparencyOfPayments': 55.305662858667425,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 83.93478260869566,
#    'CompensationAndBenefits': 72.25160219966568,
#    'CompensationAndBenefitsIndustryPercentile': 77,
#    'DiversityAndInclusion': 50.50491368981479,
#    'DiversityAndInclusionIndustryPercentile': 72,
#    'LifecycleImpactsOfProductsAndServices': 22.290374258216783,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 12.1,
#    'SystemicRiskManagement': 37.18900070586878,
#    'SystemicRiskManagementIndustryPercentile': 42.074999999999996},
#   'volume': {'AllCategoriesArticleVolumeTTM': 557,
#    'SasbMaterialityArticleVolumeTTM': 249,
#    'AllCategoriesCategoryVolumeTTM': 838,
#    'SasbMaterialityCategoryVolumeTTM': 283,
#    'AllCategoriesCategoryVolumeDaily': 6,
#    'SasbMaterialityCategoryVolumeDaily': 1,
#    'AllCategoriesArticleVolumeDaily': 2,
#    'SasbMaterialityArticleVolumeDaily': 1,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 86,
#    'CompensationAndBenefitsDaily': 0,
#    'CompensationAndBenefitsTTM': 66,
#    'DiversityAndInclusionDaily': 0,
#    'DiversityAndInclusionTTM': 53,
#    'LifecycleImpactsOfProductsAndServicesDaily': 1,
#    'LifecycleImpactsOfProductsAndServicesTTM': 59,
#    'SystemicRiskManagementDaily': 0,
#    'SystemicRiskManagementTTM': 19},
#   'articleList': []},
#  'US0846707026': {'ISIN': 'US0846707026',
#   'CUSIP': '084670702',
#   'SEDOL': '2073390',
#   'TICKER': 'BRK/B',
#   'companyName': 'Berkshire Hathaway',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 67.06021057659785,
#    'MaterialityScoreIndustryPercentile': 73.58108108108108,
#    'CustomerWelfare': 61.77018229281834,
#    'CustomerWelfareIndustryPercentile': 75.13392857142857,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 73.32396788199662,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 82.38214285714287,
#    'FairMarketingAndAdvertising': 43.54130692255015,
#    'FairMarketingAndAdvertisingIndustryPercentile': 46.588235294117645,
#    'LifecycleImpactsOfProductsAndServices': 66.86980490089486,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 44.785714285714285,
#    'SystemicRiskManagement': 32.683157088096095,
#    'SystemicRiskManagementIndustryPercentile': 9.580645161290322},
#   'pulse': {'MaterialityScore': 84.02004773700962,
#    'CustomerWelfare': 75.67111046490704,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 75.47602861861434,
#    'FairMarketingAndAdvertising': 8.306864828759355,
#    'LifecycleImpactsOfProductsAndServices': 87.30478632348134,
#    'SystemicRiskManagement': 25.413340124741172},
#   'momentum': {'MaterialityScore': 82.20048663840203,
#    'MaterialityScoreIndustryPercentile': 84.28378378378378,
#    'CustomerWelfare': 87.02590148293079,
#    'CustomerWelfareIndustryPercentile': 87.50892857142857,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 85.13109611014794,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 88.39285714285715,
#    'FairMarketingAndAdvertising': 15.35643314380416,
#    'FairMarketingAndAdvertisingIndustryPercentile': 7.764705882352941,
#    'LifecycleImpactsOfProductsAndServices': 82.53650860620982,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 88.78571428571429,
#    'SystemicRiskManagement': 16.226821420235893,
#    'SystemicRiskManagementIndustryPercentile': 7.983870967741935},
#   'volume': {'AllCategoriesArticleVolumeTTM': 168,
#    'SasbMaterialityArticleVolumeTTM': 66,
#    'AllCategoriesCategoryVolumeTTM': 248,
#    'SasbMaterialityCategoryVolumeTTM': 66,
#    'AllCategoriesCategoryVolumeDaily': 2,
#    'SasbMaterialityCategoryVolumeDaily': 1,
#    'AllCategoriesArticleVolumeDaily': 1,
#    'SasbMaterialityArticleVolumeDaily': 1,
#    'CustomerWelfareDaily': 0,
#    'CustomerWelfareTTM': 13,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsDaily': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsTTM': 29,
#    'FairMarketingAndAdvertisingDaily': 0,
#    'FairMarketingAndAdvertisingTTM': 2,
#    'LifecycleImpactsOfProductsAndServicesDaily': 1,
#    'LifecycleImpactsOfProductsAndServicesTTM': 20,
#    'SystemicRiskManagementDaily': 0,
#    'SystemicRiskManagementTTM': 2},
#   'articleList': []},
#  'US30231G1022': {'ISIN': 'US30231G1022',
#   'CUSIP': '30231G102',
#   'SEDOL': '2326618',
#   'TICKER': 'XOM',
#   'companyName': 'Exxon Mobil',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 42.07475622984948,
#    'MaterialityScoreIndustryPercentile': 29.924999999999997,
#    'AccidentAndSafetyManagement': 37.22582011420652,
#    'AccidentAndSafetyManagementIndustryPercentile': 31.46186440677966,
#    'AirQuality': 37.340812544274236,
#    'AirQualityIndustryPercentile': 30.1304347826087,
#    'BiodiversityImpacts': 38.89253596849901,
#    'BiodiversityImpactsIndustryPercentile': 27.60576923076923,
#    'BusinessEthicsAndTransparencyOfPayments': 29.76141279911952,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 48.330708661417326,
#    'EmployeeHealthSafetyAndWellbeing': 43.93050907372151,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 28.285714285714285,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 44.63210422602494,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 27.291891891891893,
#    'GHGEmissions': 42.99147953392244,
#    'GHGEmissionsIndustryPercentile': 18.293478260869563,
#    'HumanRightsAndCommunityRelations': 34.15347228005956,
#    'HumanRightsAndCommunityRelationsIndustryPercentile': 39.9327731092437,
#    'RegulatoryCaptureAndPoliticalInfluence': 48.67568184714531,
#    'RegulatoryCaptureAndPoliticalInfluenceIndustryPercentile': 39.50917431192661,
#    'WaterAndWastewaterManagement': 45.13373967228229,
#    'WaterAndWastewaterManagementIndustryPercentile': 31.61344537815126},
#   'pulse': {'MaterialityScore': 43.858864400530926,
#    'AccidentAndSafetyManagement': 49.539890933661354,
#    'AirQuality': 49.47431567095063,
#    'BiodiversityImpacts': 56.86502301653318,
#    'BusinessEthicsAndTransparencyOfPayments': 35.58486421877539,
#    'EmployeeHealthSafetyAndWellbeing': 71.40592515885005,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 39.91509461411843,
#    'GHGEmissions': 45.644240556120245,
#    'HumanRightsAndCommunityRelations': 27.3163318447237,
#    'RegulatoryCaptureAndPoliticalInfluence': 45.88963150328026,
#    'WaterAndWastewaterManagement': 42.47393245156554},
#   'momentum': {'MaterialityScore': 73.75351999060847,
#    'MaterialityScoreIndustryPercentile': 70.875,
#    'AccidentAndSafetyManagement': 59.40197788952227,
#    'AccidentAndSafetyManagementIndustryPercentile': 60.406779661016955,
#    'AirQuality': 78.96453784963828,
#    'AirQualityIndustryPercentile': 78.55434782608695,
#    'BiodiversityImpacts': 77.33553684538477,
#    'BiodiversityImpactsIndustryPercentile': 77.10576923076923,
#    'BusinessEthicsAndTransparencyOfPayments': 21.570586240209146,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 17.539370078740156,
#    'EmployeeHealthSafetyAndWellbeing': 73.44479292557594,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 74.52197802197801,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 48.22876341200122,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 37.45945945945946,
#    'GHGEmissions': 82.91504424005085,
#    'GHGEmissionsIndustryPercentile': 85.54891304347825,
#    'HumanRightsAndCommunityRelations': 60.639540474998284,
#    'HumanRightsAndCommunityRelationsIndustryPercentile': 74.45798319327731,
#    'RegulatoryCaptureAndPoliticalInfluence': 68.041010977318,
#    'RegulatoryCaptureAndPoliticalInfluenceIndustryPercentile': 71.29816513761467,
#    'WaterAndWastewaterManagement': 72.0384666041461,
#    'WaterAndWastewaterManagementIndustryPercentile': 78.61764705882352},
#   'volume': {'AllCategoriesArticleVolumeTTM': 994,
#    'SasbMaterialityArticleVolumeTTM': 811,
#    'AllCategoriesCategoryVolumeTTM': 2285,
#    'SasbMaterialityCategoryVolumeTTM': 1389,
#    'AllCategoriesCategoryVolumeDaily': 2,
#    'SasbMaterialityCategoryVolumeDaily': 1,
#    'AllCategoriesArticleVolumeDaily': 2,
#    'SasbMaterialityArticleVolumeDaily': 1,
#    'AccidentAndSafetyManagementDaily': 0,
#    'AccidentAndSafetyManagementTTM': 74,
#    'AirQualityDaily': 0,
#    'AirQualityTTM': 16,
#    'BiodiversityImpactsDaily': 0,
#    'BiodiversityImpactsTTM': 52,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 67,
#    'EmployeeHealthSafetyAndWellbeingDaily': 0,
#    'EmployeeHealthSafetyAndWellbeingTTM': 39,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsDaily': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsTTM': 358,
#    'GHGEmissionsDaily': 0,
#    'GHGEmissionsTTM': 523,
#    'HumanRightsAndCommunityRelationsDaily': 0,
#    'HumanRightsAndCommunityRelationsTTM': 70,
#    'RegulatoryCaptureAndPoliticalInfluenceDaily': 1,
#    'RegulatoryCaptureAndPoliticalInfluenceTTM': 152,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 38},
#   'articleList': [{'pubDate': '2018-11-06T04:45:00.000Z',
#     'title': 'Shell, ExxonMobil May Sign Oil Swap Deals, Says NNPC',
#     'source': 'THISDAYLIVE',
#     'author': '',
#     'url': 'https://www.thisdaylive.com/index.php/2018/11/06/shell-exxonmobil-may-sign-oil-swap-deals-says-nnpc/',
#     'categories': ['RegulatoryCaptureAndPoliticalInfluence']}]},
#  'US02079K3059': {'ISIN': 'US02079K3059',
#   'CUSIP': '02079K305',
#   'SEDOL': 'BYVY8G0',
#   'TICKER': 'GOOGL',
#   'companyName': 'Alphabet Inc.',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 47.24833435382258,
#    'MaterialityScoreIndustryPercentile': 26.60625,
#    'CompetitiveBehavior': 37.35560977223137,
#    'CompetitiveBehaviorIndustryPercentile': 29.540322580645164,
#    'DataSecurityAndCustomerPrivacy': 53.97833945210507,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 47.82203389830509,
#    'DiversityAndInclusion': 44.0358215808191,
#    'DiversityAndInclusionIndustryPercentile': 21,
#    'EnergyManagement': 77.01014576126094,
#    'EnergyManagementIndustryPercentile': 56.327586206896555,
#    'RecruitmentDevelopmentAndRetention': 46.04225627092721,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 26.25,
#    'WaterAndWastewaterManagement': 58.505310102195295,
#    'WaterAndWastewaterManagementIndustryPercentile': 63.642857142857146},
#   'pulse': {'MaterialityScore': 41.94534305189428,
#    'CompetitiveBehavior': 42.1092810457819,
#    'DataSecurityAndCustomerPrivacy': 49.18351806190687,
#    'DiversityAndInclusion': 32.558508989373856,
#    'EnergyManagement': 78.02828952286687,
#    'RecruitmentDevelopmentAndRetention': 42.63635821033773,
#    'WaterAndWastewaterManagement': 55.72966101351739},
#   'momentum': {'MaterialityScore': 50,
#    'MaterialityScoreIndustryPercentile': 48.88125,
#    'CompetitiveBehavior': 31.676156482264794,
#    'CompetitiveBehaviorIndustryPercentile': 36.725806451612904,
#    'DataSecurityAndCustomerPrivacy': 39.19466360298708,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 16.779661016949152,
#    'DiversityAndInclusion': 26.405609926440032,
#    'DiversityAndInclusionIndustryPercentile': 12,
#    'EnergyManagement': 50,
#    'EnergyManagementIndustryPercentile': 44.37931034482759,
#    'RecruitmentDevelopmentAndRetention': 56.791030260015376,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 66,
#    'WaterAndWastewaterManagement': 80.89088204766746,
#    'WaterAndWastewaterManagementIndustryPercentile': 84.85714285714285},
#   'volume': {'AllCategoriesArticleVolumeTTM': 5217,
#    'SasbMaterialityArticleVolumeTTM': 3139,
#    'AllCategoriesCategoryVolumeTTM': 7954,
#    'SasbMaterialityCategoryVolumeTTM': 3601,
#    'AllCategoriesCategoryVolumeDaily': 11,
#    'SasbMaterialityCategoryVolumeDaily': 6,
#    'AllCategoriesArticleVolumeDaily': 6,
#    'SasbMaterialityArticleVolumeDaily': 3,
#    'CompetitiveBehaviorDaily': 0,
#    'CompetitiveBehaviorTTM': 760,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 1446,
#    'DiversityAndInclusionDaily': 3,
#    'DiversityAndInclusionTTM': 583,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 174,
#    'RecruitmentDevelopmentAndRetentionDaily': 3,
#    'RecruitmentDevelopmentAndRetentionTTM': 618,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 20},
#   'articleList': [{'pubDate': '2018-11-06T03:41:36.000Z',
#     'title': 'The Google walkout is a new kind of activism',
#     'source': 'Livemint.com',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37604262814&p=4la&v=1&x=eUZkiuUjLaiIyAM6_j0W1g',
#     'categories': ['DiversityAndInclusion',
#      'RecruitmentDevelopmentAndRetention',
#      'LaborRelations']},
#    {'pubDate': '2018-11-06T02:30:00.000Z',
#     'title': 'We must do better on sex harassment, says Google Ireland chief',
#     'source': 'Irish Independent',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37604031631&p=4la&v=1&x=6nCRRxBWtk70UQMYw5c7qQ',
#     'categories': ['DiversityAndInclusion',
#      'RecruitmentDevelopmentAndRetention',
#      'CompensationAndBenefits']},
#    {'pubDate': '2018-11-06T02:40:25.000Z',
#     'title': 'Controversy at Google',
#     'source': 'Business Times Singapore',
#     'author': '',
#     'url': 'http://ct.moreover.com/?a=37603839966&p=4la&v=1&x=CPFH6-CckiEu780rRnlgKw',
#     'categories': ['DiversityAndInclusion',
#      'RecruitmentDevelopmentAndRetention']},
#    {'pubDate': '2018-11-05T18:55:00.000Z',
#     'title': 'The Google Walkout: An International Working-Class Movement',
#     'source': 'Anarkismo',
#     'author': '',
#     'url': 'http://www.anarkismo.net/article/31194?userlanguage=pt&save_prefs=true',
#     'categories': ['DiversityAndInclusion',
#      'RecruitmentDevelopmentAndRetention',
#      'FairLaborPractices',
#      'LaborRelations',
#      'CompensationAndBenefits',
#      'HumanRightsAndCommunityRelations']}]},
#  'US4781601046': {'ISIN': 'US4781601046',
#   'CUSIP': '478160104',
#   'SEDOL': '2475833',
#   'TICKER': 'JNJ',
#   'companyName': 'Johnson & Johnson',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 49.60662134763026,
#    'MaterialityScoreIndustryPercentile': 19.642857142857142,
#    'AccessAndAffordability': 72.7578396600107,
#    'AccessAndAffordabilityIndustryPercentile': 52.02765957446809,
#    'BusinessEthicsAndTransparencyOfPayments': 36.320163882899536,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 44.20754716981132,
#    'CustomerWelfare': 39.43611234233138,
#    'CustomerWelfareIndustryPercentile': 16.123778501628664,
#    'EmployeeHealthSafetyAndWellbeing': 52.49119140044364,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 23.896551724137932,
#    'EnergyManagement': 75.97650307610884,
#    'EnergyManagementIndustryPercentile': 62.78048780487805,
#    'FairMarketingAndAdvertising': 46.20890812957432,
#    'FairMarketingAndAdvertisingIndustryPercentile': 41.96026490066225,
#    'HumanRightsAndCommunityRelations': 54.080939243857884,
#    'HumanRightsAndCommunityRelationsIndustryPercentile': 21.615,
#    'LifecycleImpactsOfProductsAndServices': 72.04180509435898,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 69.4375,
#    'ProductQualityAndSafety': 47.90345759156206,
#    'ProductQualityAndSafetyIndustryPercentile': 15.699029126213592,
#    'RecruitmentDevelopmentAndRetention': 51.862402563128484,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 57.29794520547945,
#    'SupplyChainManagement': 44.47166943326233,
#    'SupplyChainManagementIndustryPercentile': 11.533980582524272,
#    'WasteAndHazardousMaterialsManagement': 48.83561173281144,
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 36.83720930232558,
#    'WaterAndWastewaterManagement': 26.886235139282856,
#    'WaterAndWastewaterManagementIndustryPercentile': 13.813953488372093},
#   'pulse': {'MaterialityScore': 57.65407688145571,
#    'AccessAndAffordability': 83.12743575013208,
#    'BusinessEthicsAndTransparencyOfPayments': 81.20450206174331,
#    'CustomerWelfare': 51.68914957554957,
#    'EmployeeHealthSafetyAndWellbeing': 6.678536558584983,
#    'EnergyManagement': 68.68300000023034,
#    'FairMarketingAndAdvertising': 72.48862615876223,
#    'HumanRightsAndCommunityRelations': 48.31954205379487,
#    'LifecycleImpactsOfProductsAndServices': 59.380912823210714,
#    'ProductQualityAndSafety': 56.15746613773554,
#    'RecruitmentDevelopmentAndRetention': 53.169126762149354,
#    'SupplyChainManagement': 37.464681152505065,
#    'WasteAndHazardousMaterialsManagement': 49.59544282804623,
#    'WaterAndWastewaterManagement': 12.767081697175902},
#   'momentum': {'MaterialityScore': 46.76715393155813,
#    'MaterialityScoreIndustryPercentile': 44,
#    'AccessAndAffordability': 31.118778911462385,
#    'AccessAndAffordabilityIndustryPercentile': 16.429787234042553,
#    'BusinessEthicsAndTransparencyOfPayments': 21.513402898109284,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 18.99056603773585,
#    'CustomerWelfare': 32.88315292381539,
#    'CustomerWelfareIndustryPercentile': 39.986970684039086,
#    'EmployeeHealthSafetyAndWellbeing': 8.246318185677437,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 0,
#    'EnergyManagement': 20.989676994017593,
#    'EnergyManagementIndustryPercentile': 0,
#    'FairMarketingAndAdvertising': 88.20363073897668,
#    'FairMarketingAndAdvertisingIndustryPercentile': 90.14900662251655,
#    'HumanRightsAndCommunityRelations': 33.50936632783459,
#    'HumanRightsAndCommunityRelationsIndustryPercentile': 29.37,
#    'LifecycleImpactsOfProductsAndServices': 87.0708835842386,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 94.1875,
#    'ProductQualityAndSafety': 42.42575426885193,
#    'ProductQualityAndSafetyIndustryPercentile': 36.84466019417476,
#    'RecruitmentDevelopmentAndRetention': 49.858246124990345,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 45.092465753424655,
#    'SupplyChainManagement': 20.221049522428125,
#    'SupplyChainManagementIndustryPercentile': 6.247572815533981,
#    'WasteAndHazardousMaterialsManagement': 84.72193976944021,
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 88.63953488372093,
#    'WaterAndWastewaterManagement': 14.354605947219062,
#    'WaterAndWastewaterManagementIndustryPercentile': 4.604651162790698},
#   'volume': {'AllCategoriesArticleVolumeTTM': 430,
#    'SasbMaterialityArticleVolumeTTM': 346,
#    'AllCategoriesCategoryVolumeTTM': 873,
#    'SasbMaterialityCategoryVolumeTTM': 630,
#    'AllCategoriesCategoryVolumeDaily': 11,
#    'SasbMaterialityCategoryVolumeDaily': 7,
#    'AllCategoriesArticleVolumeDaily': 4,
#    'SasbMaterialityArticleVolumeDaily': 4,
#    'AccessAndAffordabilityDaily': 1,
#    'AccessAndAffordabilityTTM': 67,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 30,
#    'CustomerWelfareDaily': 3,
#    'CustomerWelfareTTM': 151,
#    'EmployeeHealthSafetyAndWellbeingDaily': 0,
#    'EmployeeHealthSafetyAndWellbeingTTM': 5,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 1,
#    'FairMarketingAndAdvertisingDaily': 0,
#    'FairMarketingAndAdvertisingTTM': 15,
#    'HumanRightsAndCommunityRelationsDaily': 0,
#    'HumanRightsAndCommunityRelationsTTM': 97,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 19,
#    'ProductQualityAndSafetyDaily': 3,
#    'ProductQualityAndSafetyTTM': 173,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 14,
#    'SupplyChainManagementDaily': 0,
#    'SupplyChainManagementTTM': 53,
#    'WasteAndHazardousMaterialsManagementDaily': 0,
#    'WasteAndHazardousMaterialsManagementTTM': 3,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 2},
#   'articleList': []},
#  'US0605051046': {'ISIN': 'US0605051046',
#   'CUSIP': '060505104',
#   'SEDOL': '2295677',
#   'TICKER': 'BAC',
#   'companyName': 'Bank of America',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 55.207331586029724,
#    'MaterialityScoreIndustryPercentile': 47.85608856088561,
#    'AccessAndAffordability': 66.50135887056993,
#    'AccessAndAffordabilityIndustryPercentile': 46.47709923664122,
#    'BusinessEthicsAndTransparencyOfPayments': 33.71465267772299,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 52.10526315789473,
#    'DataSecurityAndCustomerPrivacy': 61.81629566319606,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 65.50746268656717,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 47.68406356142504,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 28.341176470588234,
#    'LifecycleImpactsOfProductsAndServices': 64.30599008596137,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 40.8839590443686,
#    'SystemicRiskManagement': 50.09078223007554,
#    'SystemicRiskManagementIndustryPercentile': 44.85379061371841},
#   'pulse': {'MaterialityScore': 66.14836930878386,
#    'AccessAndAffordability': 73.21216746120595,
#    'BusinessEthicsAndTransparencyOfPayments': 57.35409828609547,
#    'DataSecurityAndCustomerPrivacy': 53.364073841840444,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 77.54488836800269,
#    'LifecycleImpactsOfProductsAndServices': 55.791626791684976,
#    'SystemicRiskManagement': 58.57422363420894},
#   'momentum': {'MaterialityScore': 39.5859355343847,
#    'MaterialityScoreIndustryPercentile': 34.79612546125461,
#    'AccessAndAffordability': 61.134642743709,
#    'AccessAndAffordabilityIndustryPercentile': 63.480916030534345,
#    'BusinessEthicsAndTransparencyOfPayments': 42.955245595253196,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 36.06232686980609,
#    'DataSecurityAndCustomerPrivacy': 68.75247458281721,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 80.03731343283583,
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 10.822733439588772,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 5.241176470588235,
#    'LifecycleImpactsOfProductsAndServices': 80.82341955629182,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 82.7815699658703,
#    'SystemicRiskManagement': 25.150909795803145,
#    'SystemicRiskManagementIndustryPercentile': 19.120938628158843},
#   'volume': {'AllCategoriesArticleVolumeTTM': 401,
#    'SasbMaterialityArticleVolumeTTM': 240,
#    'AllCategoriesCategoryVolumeTTM': 588,
#    'SasbMaterialityCategoryVolumeTTM': 254,
#    'AllCategoriesCategoryVolumeDaily': 3,
#    'SasbMaterialityCategoryVolumeDaily': 2,
#    'AllCategoriesArticleVolumeDaily': 2,
#    'SasbMaterialityArticleVolumeDaily': 2,
#    'AccessAndAffordabilityDaily': 2,
#    'AccessAndAffordabilityTTM': 126,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 61,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 14,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsDaily': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsTTM': 9,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 24,
#    'SystemicRiskManagementDaily': 0,
#    'SystemicRiskManagementTTM': 20},
#   'articleList': []},
#  'US4581401001': {'ISIN': 'US4581401001',
#   'CUSIP': '458140100',
#   'SEDOL': '2463247',
#   'TICKER': 'INTC',
#   'companyName': 'Intel Corp.',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 65.2757629823901,
#    'MaterialityScoreIndustryPercentile': 43.63815789473684,
#    'CompetitiveBehavior': 49.92153468489267,
#    'CompetitiveBehaviorIndustryPercentile': 47.471311475409834,
#    'EmployeeHealthSafetyAndWellbeing': 55.540114606263494,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 32.23255813953489,
#    'EnergyManagement': 76.046975189426,
#    'EnergyManagementIndustryPercentile': 53.200934579439256,
#    'GHGEmissions': 72.56785424989,
#    'GHGEmissionsIndustryPercentile': 77,
#    'LifecycleImpactsOfProductsAndServices': 71.18445530223138,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 29.835616438356162,
#    'MaterialsSourcing': 51.35292923867581,
#    'MaterialsSourcingIndustryPercentile': 36.3,
#    'RecruitmentDevelopmentAndRetention': 47.90953959377947,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 35.95263157894737,
#    'WasteAndHazardousMaterialsManagement': 39.716011640908114,
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 18.72972972972973,
#    'WaterAndWastewaterManagement': 72.19598837438254,
#    'WaterAndWastewaterManagementIndustryPercentile': 83.36842105263158},
#   'pulse': {'MaterialityScore': 55.49080532896729,
#    'CompetitiveBehavior': 37.99406995555167,
#    'EmployeeHealthSafetyAndWellbeing': 65.60736865107963,
#    'EnergyManagement': 71.3542537429453,
#    'GHGEmissions': 60.69932453140592,
#    'LifecycleImpactsOfProductsAndServices': 54.36757372309507,
#    'MaterialsSourcing': 52.25434433649687,
#    'RecruitmentDevelopmentAndRetention': 56.347283799943234,
#    'WasteAndHazardousMaterialsManagement': 49.99695166358829,
#    'WaterAndWastewaterManagement': 70.90061475999666},
#   'momentum': {'MaterialityScore': 50,
#    'MaterialityScoreIndustryPercentile': 47.22039473684211,
#    'CompetitiveBehavior': 67.92520091179814,
#    'CompetitiveBehaviorIndustryPercentile': 74.65573770491802,
#    'EmployeeHealthSafetyAndWellbeing': 29.252627692230536,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 9.209302325581396,
#    'EnergyManagement': 50,
#    'EnergyManagementIndustryPercentile': 41.17289719626168,
#    'GHGEmissions': 34.31470990986296,
#    'GHGEmissionsIndustryPercentile': 17.6,
#    'LifecycleImpactsOfProductsAndServices': 50,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 37.97260273972603,
#    'MaterialsSourcing': 23.051458890029643,
#    'MaterialsSourcingIndustryPercentile': 10.725,
#    'RecruitmentDevelopmentAndRetention': 27.6800653436644,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 13.547368421052633,
#    'WasteAndHazardousMaterialsManagement': 16.24531726386826,
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 5.351351351351352,
#    'WaterAndWastewaterManagement': 75.1360324633934,
#    'WaterAndWastewaterManagementIndustryPercentile': 85.97368421052632},
#   'volume': {'AllCategoriesArticleVolumeTTM': 1067,
#    'SasbMaterialityArticleVolumeTTM': 546,
#    'AllCategoriesCategoryVolumeTTM': 1482,
#    'SasbMaterialityCategoryVolumeTTM': 615,
#    'AllCategoriesCategoryVolumeDaily': 9,
#    'SasbMaterialityCategoryVolumeDaily': 3,
#    'AllCategoriesArticleVolumeDaily': 7,
#    'SasbMaterialityArticleVolumeDaily': 3,
#    'CompetitiveBehaviorDaily': 0,
#    'CompetitiveBehaviorTTM': 62,
#    'EmployeeHealthSafetyAndWellbeingDaily': 0,
#    'EmployeeHealthSafetyAndWellbeingTTM': 11,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 61,
#    'GHGEmissionsDaily': 0,
#    'GHGEmissionsTTM': 8,
#    'LifecycleImpactsOfProductsAndServicesDaily': 3,
#    'LifecycleImpactsOfProductsAndServicesTTM': 369,
#    'MaterialsSourcingDaily': 0,
#    'MaterialsSourcingTTM': 8,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 85,
#    'WasteAndHazardousMaterialsManagementDaily': 0,
#    'WasteAndHazardousMaterialsManagementTTM': 5,
# ...
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 'NA',
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 'NA',
#    'SystemicRiskManagement': 'NA',
#    'SystemicRiskManagementIndustryPercentile': 'NA'},
#   'volume': {'AllCategoriesArticleVolumeTTM': 0,
#    'SasbMaterialityArticleVolumeTTM': 0,
#    'AllCategoriesCategoryVolumeTTM': 0,
#    'SasbMaterialityCategoryVolumeTTM': 0,
#    'AllCategoriesCategoryVolumeDaily': 1,
#    'SasbMaterialityCategoryVolumeDaily': 0,
#    'AllCategoriesArticleVolumeDaily': 1,
#    'AccessAndAffordabilityDaily': 0,
#    'AccessAndAffordabilityTTM': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 0,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsDaily': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsTTM': 0,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 0,
#    'SystemicRiskManagementDaily': 0,
#    'SystemicRiskManagementTTM': 0},
#   'articleList': []},
#  'US09257W1009': {'error': 'No Data for This Entity'},
#  'US1972361026': {'ISIN': 'US1972361026',
#   'CUSIP': '197236102',
#   'SEDOL': '2176608',
#   'TICKER': 'COLB',
#   'companyName': 'Columbia Banking System',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 46.36141076298969,
#    'MaterialityScoreIndustryPercentile': 29.86439114391144,
#    'AccessAndAffordability': 50.001516483490505,
#    'AccessAndAffordabilityIndustryPercentile': 12.973282442748092,
#    'BusinessEthicsAndTransparencyOfPayments': 46.36132891938536,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 75.82686980609418,
#    'DataSecurityAndCustomerPrivacy': 'NA',
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 'NA',
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 'NA',
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 'NA',
#    'SystemicRiskManagement': 'NA',
#    'SystemicRiskManagementIndustryPercentile': 'NA'},
#   'pulse': {'MaterialityScore': 46.01,
#    'AccessAndAffordability': 50.00143896186456,
#    'BusinessEthicsAndTransparencyOfPayments': 46.01,
#    'DataSecurityAndCustomerPrivacy': 'NA',
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'SystemicRiskManagement': 'NA'},
#   'momentum': {'MaterialityScore': 39.6095754858744,
#    'MaterialityScoreIndustryPercentile': 34.79612546125461,
#    'AccessAndAffordability': 50,
#    'AccessAndAffordabilityIndustryPercentile': 42.3206106870229,
#    'BusinessEthicsAndTransparencyOfPayments': 39.7509187074931,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 35.23961218836565,
#    'DataSecurityAndCustomerPrivacy': 'NA',
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 'NA',
#    'EnvironmentalSocialImpactsOnAssetsAndOperations': 'NA',
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsIndustryPercentile': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 'NA',
#    'SystemicRiskManagement': 'NA',
#    'SystemicRiskManagementIndustryPercentile': 'NA'},
#   'volume': {'AllCategoriesArticleVolumeTTM': 1,
#    'SasbMaterialityArticleVolumeTTM': 0,
#    'AllCategoriesCategoryVolumeTTM': 1,
#    'SasbMaterialityCategoryVolumeTTM': 0,
#    'AllCategoriesCategoryVolumeDaily': 1,
#    'SasbMaterialityCategoryVolumeDaily': 0,
#    'AllCategoriesArticleVolumeDaily': 1,
#    'AccessAndAffordabilityDaily': 0,
#    'AccessAndAffordabilityTTM': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 0,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsDaily': 0,
#    'EnvironmentalSocialImpactsOnAssetsAndOperationsTTM': 0,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 0,
#    'SystemicRiskManagementDaily': 0,
#    'SystemicRiskManagementTTM': 0},
#   'articleList': []},
#  'US78470V1089': {'error': 'ISIN Not Found: US78470V1089'},
#  'US55608B1052': {'ISIN': 'US55608B1052',
#   'CUSIP': '55608B105',
#   'SEDOL': 'B1Z4VB1',
#   'TICKER': 'MIC',
#   'companyName': 'Macquarie Infrastructure',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 58.554210308659,
#    'MaterialityScoreIndustryPercentile': 54.725,
#    'BusinessEthicsAndTransparencyOfPayments': 39.738703195636496,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 52.88461538461539,
#    'DataSecurityAndCustomerPrivacy': 69.9945,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 84.54424778761062,
#    'DiversityAndInclusion': 64.63458618911937,
#    'DiversityAndInclusionIndustryPercentile': 35.35714285714286,
#    'RecruitmentDevelopmentAndRetention': 74.627,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 78.92307692307692},
#   'pulse': {'MaterialityScore': 35.05702084745009,
#    'BusinessEthicsAndTransparencyOfPayments': 32.656006669147196,
#    'DataSecurityAndCustomerPrivacy': 69.9945,
#    'DiversityAndInclusion': 64.63458618911937,
#    'RecruitmentDevelopmentAndRetention': 74.627},
#   'momentum': {'MaterialityScore': 9.974801655310106,
#    'MaterialityScoreIndustryPercentile': 4.95,
#    'BusinessEthicsAndTransparencyOfPayments': 16.321722936571113,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 17.76923076923077,
#    'DataSecurityAndCustomerPrivacy': 50,
#    'DataSecurityAndCustomerPrivacyIndustryPercentile': 44.243362831858406,
#    'DiversityAndInclusion': 50,
#    'DiversityAndInclusionIndustryPercentile': 40.30714285714286,
#    'RecruitmentDevelopmentAndRetention': 50,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 46.03846153846154},
#   'volume': {'AllCategoriesArticleVolumeTTM': 24,
#    'SasbMaterialityArticleVolumeTTM': 8,
#    'AllCategoriesCategoryVolumeTTM': 34,
#    'SasbMaterialityCategoryVolumeTTM': 9,
#    'AllCategoriesCategoryVolumeDaily': 2,
#    'SasbMaterialityCategoryVolumeDaily': 0,
#    'AllCategoriesArticleVolumeDaily': 1,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 6,
#    'DataSecurityAndCustomerPrivacyDaily': 0,
#    'DataSecurityAndCustomerPrivacyTTM': 0,
#    'DiversityAndInclusionDaily': 0,
#    'DiversityAndInclusionTTM': 2,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 1},
#   'articleList': []},
#  'US03152W1099': {'ISIN': 'US03152W1099',
#   'CUSIP': '03152W109',
#   'SEDOL': 'B19FQ48',
#   'TICKER': 'FOLD',
#   'companyName': 'Amicus Therapeutics',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 71.73023293234533,
#    'MaterialityScoreIndustryPercentile': 65.37142857142857,
#    'AccessAndAffordability': 93.57582433713661,
#    'AccessAndAffordabilityIndustryPercentile': 94.7872340425532,
#    'BusinessEthicsAndTransparencyOfPayments': 12.051846739191683,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 2.80188679245283,
#    'CustomerWelfare': 58.22524212940472,
#    'CustomerWelfareIndustryPercentile': 48.855048859934854,
#    'EmployeeHealthSafetyAndWellbeing': 'NA',
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 'NA',
#    'EnergyManagement': 'NA',
#    'EnergyManagementIndustryPercentile': 'NA',
#    'FairMarketingAndAdvertising': 55.08200000000013,
#    'FairMarketingAndAdvertisingIndustryPercentile': 61.62913907284768,
#    'HumanRightsAndCommunityRelations': 78.61514818925146,
#    'HumanRightsAndCommunityRelationsIndustryPercentile': 63.525000000000006,
#    'LifecycleImpactsOfProductsAndServices': 62.95347972983182,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 43.770833333333336,
#    'ProductQualityAndSafety': 74.5605836934502,
#    'ProductQualityAndSafetyIndustryPercentile': 63.59708737864077,
#    'RecruitmentDevelopmentAndRetention': 25.775500000000026,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 10.51027397260274,
#    'SupplyChainManagement': 'NA',
#    'SupplyChainManagementIndustryPercentile': 'NA',
#    'WasteAndHazardousMaterialsManagement': 20.220666666666663,
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 4.604651162790698,
#    'WaterAndWastewaterManagement': 'NA',
#    'WaterAndWastewaterManagementIndustryPercentile': 'NA'},
#   'pulse': {'MaterialityScore': 50.01061000389552,
#    'AccessAndAffordability': 98.12621381854126,
#    'BusinessEthicsAndTransparencyOfPayments': 9.281000247296365,
#    'CustomerWelfare': 27.508248888069183,
#    'EmployeeHealthSafetyAndWellbeing': 'NA',
#    'EnergyManagement': 'NA',
#    'FairMarketingAndAdvertising': 55.082,
#    'HumanRightsAndCommunityRelations': 66.89042939676195,
#    'LifecycleImpactsOfProductsAndServices': 62.9234175357119,
#    'ProductQualityAndSafety': 55.3780976145491,
#    'RecruitmentDevelopmentAndRetention': 25.775499999999997,
#    'SupplyChainManagement': 'NA',
#    'WasteAndHazardousMaterialsManagement': 20.220666666666663,
#    'WaterAndWastewaterManagement': 'NA'},
#   'momentum': {'MaterialityScore': 84.11762309984472,
#    'MaterialityScoreIndustryPercentile': 81.08571428571429,
#    'AccessAndAffordability': 83.84015214680853,
#    'AccessAndAffordabilityIndustryPercentile': 84.88723404255319,
#    'BusinessEthicsAndTransparencyOfPayments': 19.886065151671676,
#    'BusinessEthicsAndTransparencyOfPaymentsIndustryPercentile': 14.632075471698112,
#    'CustomerWelfare': 84.51485911904841,
#    'CustomerWelfareIndustryPercentile': 81.26384364820848,
#    'EmployeeHealthSafetyAndWellbeing': 'NA',
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 'NA',
#    'EnergyManagement': 'NA',
#    'EnergyManagementIndustryPercentile': 'NA',
#    'FairMarketingAndAdvertising': 50,
#    'FairMarketingAndAdvertisingIndustryPercentile': 48.51655629139073,
#    'HumanRightsAndCommunityRelations': 79.77802833314766,
#    'HumanRightsAndCommunityRelationsIndustryPercentile': 76.395,
#    'LifecycleImpactsOfProductsAndServices': 50,
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 42.166666666666664,
#    'ProductQualityAndSafety': 84.7540823074703,
#    'ProductQualityAndSafetyIndustryPercentile': 84.58252427184466,
#    'RecruitmentDevelopmentAndRetention': 50,
#    'RecruitmentDevelopmentAndRetentionIndustryPercentile': 45.092465753424655,
#    'SupplyChainManagement': 'NA',
#    'SupplyChainManagementIndustryPercentile': 'NA',
#    'WasteAndHazardousMaterialsManagement': 50,
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 41.44186046511628,
#    'WaterAndWastewaterManagement': 'NA',
#    'WaterAndWastewaterManagementIndustryPercentile': 'NA'},
#   'volume': {'AllCategoriesArticleVolumeTTM': 33,
#    'SasbMaterialityArticleVolumeTTM': 31,
#    'AllCategoriesCategoryVolumeTTM': 95,
#    'SasbMaterialityCategoryVolumeTTM': 79,
#    'AllCategoriesCategoryVolumeDaily': 2,
#    'SasbMaterialityCategoryVolumeDaily': 2,
#    'AllCategoriesArticleVolumeDaily': 1,
#    'SasbMaterialityArticleVolumeDaily': 1,
#    'AccessAndAffordabilityDaily': 0,
#    'AccessAndAffordabilityTTM': 3,
#    'BusinessEthicsAndTransparencyOfPaymentsDaily': 0,
#    'BusinessEthicsAndTransparencyOfPaymentsTTM': 0,
#    'CustomerWelfareDaily': 1,
#    'CustomerWelfareTTM': 18,
#    'EmployeeHealthSafetyAndWellbeingDaily': 0,
#    'EmployeeHealthSafetyAndWellbeingTTM': 0,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 0,
#    'FairMarketingAndAdvertisingDaily': 0,
#    'FairMarketingAndAdvertisingTTM': 3,
#    'HumanRightsAndCommunityRelationsDaily': 0,
#    'HumanRightsAndCommunityRelationsTTM': 25,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 0,
#    'ProductQualityAndSafetyDaily': 1,
#    'ProductQualityAndSafetyTTM': 28,
#    'RecruitmentDevelopmentAndRetentionDaily': 0,
#    'RecruitmentDevelopmentAndRetentionTTM': 0,
#    'SupplyChainManagementDaily': 0,
#    'SupplyChainManagementTTM': 0,
#    'WasteAndHazardousMaterialsManagementDaily': 0,
#    'WasteAndHazardousMaterialsManagementTTM': 2,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 0},
#   'articleList': []},
#  'US86614U1007': {'ISIN': 'US86614U1007',
#   'CUSIP': '86614U100',
#   'SEDOL': 'BW9JPS4',
#   'TICKER': 'SUM',
#   'companyName': 'Summit Materials',
#   'mode': 'Insight360 SASB Edition API',
#   'date': '2018-11-05T00:00:00.000Z',
#   'hourMs': 1541376000000,
#   'insight': {'MaterialityScore': 81.46655194787404,
#    'MaterialityScoreIndustryPercentile': 85.4274193548387,
#    'AirQuality': 'NA',
#    'AirQualityIndustryPercentile': 'NA',
#    'BiodiversityImpacts': 'NA',
#    'BiodiversityImpactsIndustryPercentile': 'NA',
#    'CompetitiveBehavior': 73.64450000000001,
#    'CompetitiveBehaviorIndustryPercentile': 88,
#    'EmployeeHealthSafetyAndWellbeing': 71.23993990381936,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 33,
#    'EnergyManagement': 'NA',
#    'EnergyManagementIndustryPercentile': 'NA',
#    'GHGEmissions': 'NA',
#    'GHGEmissionsIndustryPercentile': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 'NA',
#    'WasteAndHazardousMaterialsManagement': 'NA',
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 'NA',
#    'WaterAndWastewaterManagement': 'NA',
#    'WaterAndWastewaterManagementIndustryPercentile': 'NA'},
#   'pulse': {'MaterialityScore': 81.52308100159779,
#    'AirQuality': 'NA',
#    'BiodiversityImpacts': 'NA',
#    'CompetitiveBehavior': 73.64450000000001,
#    'EmployeeHealthSafetyAndWellbeing': 71.22452716099318,
#    'EnergyManagement': 'NA',
#    'GHGEmissions': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'WasteAndHazardousMaterialsManagement': 'NA',
#    'WaterAndWastewaterManagement': 'NA'},
#   'momentum': {'MaterialityScore': 50,
#    'MaterialityScoreIndustryPercentile': 45.50806451612903,
#    'AirQuality': 'NA',
#    'AirQualityIndustryPercentile': 'NA',
#    'BiodiversityImpacts': 'NA',
#    'BiodiversityImpactsIndustryPercentile': 'NA',
#    'CompetitiveBehavior': 50,
#    'CompetitiveBehaviorIndustryPercentile': 42.625,
#    'EmployeeHealthSafetyAndWellbeing': 50,
#    'EmployeeHealthSafetyAndWellbeingIndustryPercentile': 37.125,
#    'EnergyManagement': 'NA',
#    'EnergyManagementIndustryPercentile': 'NA',
#    'GHGEmissions': 'NA',
#    'GHGEmissionsIndustryPercentile': 'NA',
#    'LifecycleImpactsOfProductsAndServices': 'NA',
#    'LifecycleImpactsOfProductsAndServicesIndustryPercentile': 'NA',
#    'WasteAndHazardousMaterialsManagement': 'NA',
#    'WasteAndHazardousMaterialsManagementIndustryPercentile': 'NA',
#    'WaterAndWastewaterManagement': 'NA',
#    'WaterAndWastewaterManagementIndustryPercentile': 'NA'},
#   'volume': {'AllCategoriesArticleVolumeTTM': 0,
#    'SasbMaterialityArticleVolumeTTM': 0,
#    'AllCategoriesCategoryVolumeTTM': 0,
#    'SasbMaterialityCategoryVolumeTTM': 0,
#    'AllCategoriesCategoryVolumeDaily': 1,
#    'SasbMaterialityCategoryVolumeDaily': 0,
#    'AllCategoriesArticleVolumeDaily': 1,
#    'AirQualityDaily': 0,
#    'AirQualityTTM': 0,
#    'BiodiversityImpactsDaily': 0,
#    'BiodiversityImpactsTTM': 0,
#    'CompetitiveBehaviorDaily': 0,
#    'CompetitiveBehaviorTTM': 0,
#    'EmployeeHealthSafetyAndWellbeingDaily': 0,
#    'EmployeeHealthSafetyAndWellbeingTTM': 0,
#    'EnergyManagementDaily': 0,
#    'EnergyManagementTTM': 0,
#    'GHGEmissionsDaily': 0,
#    'GHGEmissionsTTM': 0,
#    'LifecycleImpactsOfProductsAndServicesDaily': 0,
#    'LifecycleImpactsOfProductsAndServicesTTM': 0,
#    'WasteAndHazardousMaterialsManagementDaily': 0,
#    'WasteAndHazardousMaterialsManagementTTM': 0,
#    'WaterAndWastewaterManagementDaily': 0,
#    'WaterAndWastewaterManagementTTM': 0},
#   'articleList': []},
#  ...}

# %%
# with open('full_scores.json', 'w') as fout:
#     json.dump(full_scores, fout)

# %%
def get_momentum_report(isin, start_date='2018-10-01', end_date='2018-10-31', percentile='true', metrics='allmaterial'):
    momentum_url = API_ENDPOINT + 'data/companies/' + isin + '/momentum'
    momentum_payload = {
        'start_date': start_date,
        'end_date': end_date,
        'percentile': percentile,
        'metrics': metrics,
    }
    isin_json = make_request(url=momentum_url, params=momentum_payload, doPrint=False)
    return isin_json
full_momentum = {isin: get_momentum_report(isin) for isin in isins}

# %%
full_momentum
